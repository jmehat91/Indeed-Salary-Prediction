# %%
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
# pd.set_option('display.max_rows', None)

# %%
#loaded in all webscapes as separate dataframes
results_2 = pd.read_csv('web scrapes/results_v2.csv')
results_3 = pd.read_csv('web scrapes/results_v3.csv')
results_4 = pd.read_csv('web scrapes/results_v4.csv')
results_5 = pd.read_csv('web scrapes/results_v5.csv')
results_6 = pd.read_csv('web scrapes/results_v6.csv')
results_7 = pd.read_csv('web scrapes/results_v7.csv')
results_8 = pd.read_csv('web scrapes/results_v8.csv')
results_9 = pd.read_csv('web scrapes/results_v9.csv')
results_10 = pd.read_csv('web scrapes/results_v10.csv')
results_11 = pd.read_csv('web scrapes/results_v11.csv')
results_12 = pd.read_csv('web scrapes/results_v12.csv')
results_13 = pd.read_csv('web scrapes/results_v13.csv')
results_14 = pd.read_csv('web scrapes/results_v14.csv')
results_15 = pd.read_csv('web scrapes/results_v15.csv')
results_16 = pd.read_csv('web scrapes/results_v16.csv')
results_17 = pd.read_csv('web scrapes/results_v17.csv')
results_18 = pd.read_csv('web scrapes/results_v18.csv')
results_19 = pd.read_csv('web scrapes/results_v19.csv')
results_20 = pd.read_csv('web scrapes/results_v20.csv')

# %%
# merged all dataframes into 1 and reset the index
r3 = pd.concat([results_2, results_3, results_4, 
                results_5, results_6, results_7, 
                results_8, results_9, results_10, 
                results_11, results_12, results_13,
               results_14, results_15, results_16,
               results_17, results_18, results_19,
               results_20]).reset_index()

# %%
r3
# Out:
#        index  Unnamed: 0                                           location  \
# 0          0           0                       Denver, CO+1 location•Remote
# 1          1           1                             Denver, CO+2 locations
# 2          2           2  Denver, CO 80202 (Central Business District area)
# 3          3           3  Denver, CO 80202 (Central Business District area)
# 4          4           4                                         Denver, CO
# ...      ...         ...                                                ...
# 47422   1135        1135                                       Brooklyn, NY
# 47423   1136        1136                 Brooklyn, NY 11237 (Bushwick area)
# 47424   1137        1137                                       Endicott, NY
# 47425   1138        1138                  New York, NY 10017 (Midtown area)
# 47426   1139        1139                                     Elma, NY 14059
#
#                                                 title  \
# ...

# %%
#removed the index and unnamed:0 columns 
r3.drop(axis=1, columns=['Unnamed: 0', 'index'], inplace=True)

# %%
r3.shape
# Out:
# (47427, 4)

# %%
#find the duplicated entries
r3.duplicated().sum()
# Out:
# 30684

# %%
#dropped duplicated entries 
r3.drop_duplicates(keep='first', inplace=True)

# %%
r3.shape
# Out:
# (16743, 4)

# %%
r3.title.value_counts()
# Out:
# Business Analyst                                            718
# Data Scientist                                              594
# Data Analyst                                                543
# Senior Data Scientist                                       237
# Senior Data Analyst                                         232
#                                                            ...
# Mathematical Modeler - Quantitative Systems Pharmacology      1
# Principal Research Scientist - Artificial Intelligence        1
# Senior Software Engineer - Data                               1
# Senior Software Engineer, Deep Learning                       1
# Business Analyst-GRC                                          1
# Name: title, Length: 8931, dtype: int64

# %%
r3.salary.value_counts()
# Out:
# None                          14875
# Up to $112,700 a year            15
# $80,000 - $100,000 a year        15
# $114,700 a year                  14
# $90,000 - $120,000 a year        14
#                               ...
# $115,000 - $130,000 a year        1
# $21 - $24 an hour                 1
# $47,318 - $90,000 a year          1
# $27 - $32 an hour                 1
# $170,000 - $185,000 a year        1
# Name: salary, Length: 1087, dtype: int64

# %%
# changed None salary entries to np.nan 
r3['salary'] = r3['salary'].replace('None', np.nan)

# %%
r3.isnull().sum()
# Out:
# location        0
# title           0
# company         0
# salary      14875
# dtype: int64

# %%
#dropped null salary entries 
r3.dropna(axis=0, how='any', inplace=True)

# %%
r3.shape
# Out:
# (1868, 4)

# %%
r3.head()
# Out:
#                                             location  \
# 0                       Denver, CO+1 location•Remote
# 1                             Denver, CO+2 locations
# 2  Denver, CO 80202 (Central Business District area)
# 3  Denver, CO 80202 (Central Business District area)
# 5                                         Denver, CO
#
#                                        title                    company  \
# 0                             Data Scientist                     Oracle
# 1  Data Scientist - Nationwide Opportunities  Amazon Web Services, Inc.
# 2                      Senior Data Scientist                    Verizon
# 3                   Principal Data Scientist                    Verizon
# 5                             Data Scientist               Appcast Inc.
#
#                        salary
# 0   $99,333 - $178,795 a year
# 1  $119,300 - $160,000 a year
# 2  $117,000 - $217,000 a year
# 3  $110,000 - $204,000 a year
# 5    $70,000 - $90,000 a year

# %%
#separated location column into City and State 
r3['City'] = r3['location'].str.split(",")
r3['City']= r3['City'].str[0]
r3['State'] = r3['location'].str.split(",")
r3['State']=r3['State'].str[1]
r3['State'] = r3['State'].str[:3]
# r3.head()

# %%
#dropped original location title
r3.drop(columns='location', inplace=True)
r3.head()
# Out:
#                                        title                    company  \
# 0                             Data Scientist                     Oracle
# 1  Data Scientist - Nationwide Opportunities  Amazon Web Services, Inc.
# 2                      Senior Data Scientist                    Verizon
# 3                   Principal Data Scientist                    Verizon
# 5                             Data Scientist               Appcast Inc.
#
#                        salary    City State
# 0   $99,333 - $178,795 a year  Denver    CO
# 1  $119,300 - $160,000 a year  Denver    CO
# 2  $117,000 - $217,000 a year  Denver    CO
# 3  $110,000 - $204,000 a year  Denver    CO
# 5    $70,000 - $90,000 a year  Denver    CO

# %%
r3.shape
# Out:
# (1868, 5)

# %%
r3.State.value_counts()
# Out:
#  CO    289
#  CA    235
#  TX    218
#  NY    184
#  IL    122
#  GA    120
#  PA    101
#  MA    100
#  WA     97
#  NJ     75
#  DC     60
#  AZ     43
#  MD     41
#  VA     38
#  OR     35
#  FL     30
#  NV     16
#  DE      6
#  IN      1
# Name: State, dtype: int64

# %%
r3.shape
# Out:
# (1868, 5)

# %%
#find null values again
r3[r3.isnull().sum(axis=1)>0]
# Out:
#                                                    title  \
# 3348                         Sr. Data Scientist (Remote)
# 4169                                      Data Scientist
# 4278                                      Data Scientist
# 4286                                 Lead Data Scientist
# 4400                           Cohort Lead, Data Science
# 12865                                Senior Data Analyst
# 12943                              Senior Data Scientist
# 12981                               Manager, ML Engineer
# 15751  Data Analyst - Transportation Planning Special...
# 15786               Advanced Learning Data Analyst - 1.0
# 15889              Senior Product Manager (Data Science)
# 16711           Senior Salesforce Business Analyst (CPQ)
# 31915                         Software architect – AI/ML
# 31917                                     Data Scientist
# 32005                         Jr. Data Science Engineers
# ...

# %%
r3.isnull().sum()
# Out:
# title       0
# company     0
# salary      0
# City        0
# State      57
# dtype: int64

# %%
#removed entries with nan in State categories 
r3.dropna(axis=0, how='any', inplace=True)

# %%
r3.shape
# Out:
# (1811, 5)

# %%
r3 = r3.reset_index()

# %%
r3 = r3.drop(columns='index', axis=1)

# %%
r3['salary'].str.contains('Up').sum()
# Out:
# 65

# %%
r3['salary'].str.contains('From').sum()
# Out:
# 69

# %%
#converted salary col into a list so numerical salary can be extracted 
r3['salary'] = r3['salary'].apply(lambda x: x.split())
r3
# Out:
#                                               title  \
# 0                                    Data Scientist
# 1         Data Scientist - Nationwide Opportunities
# 2                             Senior Data Scientist
# 3                          Principal Data Scientist
# 4                                    Data Scientist
# ...                                             ...
# 1806  Data Analyst (80k - 110k + HYBRID + BENEFITS)
# 1807                                   Data Analyst
# 1808               Director of Data & Media Science
# 1809               Machine Learning Product Manager
# 1810              Digital Data Analytics Specialist
#
#                            company                            salary  \
# 0                           Oracle   [$99,333, -, $178,795, a, year]
# 1        Amazon Web Services, Inc.  [$119,300, -, $160,000, a, year]
# 2                          Verizon  [$117,000, -, $217,000, a, year]
# ...

# %%
#salary column divided into 4 formats: 
## 1. x - y a year
## 2. x a year
## 3. up to x a year
## 4. from x a year

#created a new list of the salary or minimum salary if in a range
sal_1 = []
for i in r3['salary']:
    if i[0] == 'From':
        sal_1.append(i[1])
    elif i[0] == 'Up':
        sal_1.append(i[2])
    else:
        sal_1.append(i[0])
sal_1
# Out:
# ['$99,333',
#  '$119,300',
#  '$117,000',
#  '$110,000',
#  '$70,000',
#  '$93,800',
#  '$84,550',
#  '$55,900',
#  '$90,000',
#  '$116,200',
#  '$122,700',
#  '$80,000',
#  '$49,770',
#  '$25.80',
#  '$31.72',
#  '$72,400',
#  '$31.61',
#  '$73,462',
#  '$112,700',
#  '$54,000',
#  '$65,136',
#  '$25.80',
#  '$80,000',
#  '$82,700',
#  '$142,400',
#  '$112,700',
#  '$190,000',
#  '$65,000',
#  '$112,700',
#  '$62,400',
#  '$80,000',
#  '$70,000',
#  '$105,000',
#  '$71,316',
#  '$133,350',
#  '$46.90',
#  '$73,900',
#  '$67,351',
#  '$52,525',
#  '$20.81',
#  '$80,000',
#  '$70,000',
#  '$75,000',
#  '$120,000',
#  '$122,300',
#  '$100,000',
#  '$99,000',
#  '$88,795',
#  '$78,200',
#  '$82,800',
#  '$123,300',
#  '$60,800',
#  '$58,080',
#  '$82,800',
#  '$61,339',
#  '$70,000',
#  '$56,000',
#  '$83,000',
#  '$59,355',
#  '$85,800',
#  '$70,000',
#  '$31,200',
#  '$45',
#  '$112,700',
#  '$90,000',
#  '$97,000',
#  '$130,000',
#  '$86,400',
#  '$155,700',
#  '$68,000',
# ...

# %%
#create new column with sal_1
r3['sal_1'] = sal_1
r3
# Out:
#                                               title  \
# 0                                    Data Scientist
# 1         Data Scientist - Nationwide Opportunities
# 2                             Senior Data Scientist
# 3                          Principal Data Scientist
# 4                                    Data Scientist
# ...                                             ...
# 1806  Data Analyst (80k - 110k + HYBRID + BENEFITS)
# 1807                                   Data Analyst
# 1808               Director of Data & Media Science
# 1809               Machine Learning Product Manager
# 1810              Digital Data Analytics Specialist
#
#                            company                            salary  \
# 0                           Oracle   [$99,333, -, $178,795, a, year]
# 1        Amazon Web Services, Inc.  [$119,300, -, $160,000, a, year]
# 2                          Verizon  [$117,000, -, $217,000, a, year]
# ...

# %%
#create a list for the max salary when given in a range, or same salary as sal_1
sal_2 = []
for i in r3['salary']:
    if i[0] == 'From':
        sal_2.append(i[1])
    elif i[0] == 'Up':
        sal_2.append(i[2])
    elif len(i) == 3:
        sal_2.append(i[0])
    else:
        sal_2.append(i[2])
sal_2
# Out:
# ['$178,795',
#  '$160,000',
#  '$217,000',
#  '$204,000',
#  '$90,000',
#  '$93,800',
#  '$207,585',
#  '$155,900',
#  '$120,000',
#  '$116,200',
#  '$200,300',
#  '$90,000',
#  '$92,430',
#  '$38.70',
#  '$47.57',
#  '$126,600',
#  '$47.41',
#  '$73,462',
#  '$112,700',
#  '$70,000',
#  '$95,352',
#  '$38.70',
#  '$110,000',
#  '$117,566',
#  '$142,400',
#  '$112,700',
#  '$276,000',
#  '$75,000',
#  '$112,700',
#  '$78,000',
#  '$130,000',
#  '$130,000',
#  '$142,000',
#  '$108,108',
#  '$133,350',
#  '$70.35',
#  '$133,100',
#  '$67,351',
#  '$87,614',
#  '$24.29',
#  '$95,000',
#  '$93,000',
#  '$85,000',
#  '$130,000',
#  '$160,000',
#  '$160,000',
#  '$242,000',
#  '$130,000',
#  '$140,800',
#  '$92,000',
#  '$160,000',
#  '$91,200',
#  '$79,860',
#  '$92,000',
#  '$108,971',
#  '$90,000',
#  '$70,000',
#  '$132,600',
#  '$71,923',
#  '$150,100',
#  '$100,000',
#  '$64,800',
#  '$45',
#  '$112,700',
#  '$90,000',
#  '$126,000',
#  '$160,000',
#  '$86,400',
#  '$155,700',
# ...

# %%
#created new col for sal_2
r3['sal_2'] = sal_2
r3
# Out:
#                                               title  \
# 0                                    Data Scientist
# 1         Data Scientist - Nationwide Opportunities
# 2                             Senior Data Scientist
# 3                          Principal Data Scientist
# 4                                    Data Scientist
# ...                                             ...
# 1806  Data Analyst (80k - 110k + HYBRID + BENEFITS)
# 1807                                   Data Analyst
# 1808               Director of Data & Media Science
# 1809               Machine Learning Product Manager
# 1810              Digital Data Analytics Specialist
#
#                            company                            salary  \
# 0                           Oracle   [$99,333, -, $178,795, a, year]
# 1        Amazon Web Services, Inc.  [$119,300, -, $160,000, a, year]
# 2                          Verizon  [$117,000, -, $217,000, a, year]
# ...

# %%
#added the salary rate to new column
r3['rate'] = r3['salary'].str[-1]
r3
# Out:
#                                               title  \
# 0                                    Data Scientist
# 1         Data Scientist - Nationwide Opportunities
# 2                             Senior Data Scientist
# 3                          Principal Data Scientist
# 4                                    Data Scientist
# ...                                             ...
# 1806  Data Analyst (80k - 110k + HYBRID + BENEFITS)
# 1807                                   Data Analyst
# 1808               Director of Data & Media Science
# 1809               Machine Learning Product Manager
# 1810              Digital Data Analytics Specialist
#
#                            company                            salary  \
# 0                           Oracle   [$99,333, -, $178,795, a, year]
# 1        Amazon Web Services, Inc.  [$119,300, -, $160,000, a, year]
# 2                          Verizon  [$117,000, -, $217,000, a, year]
# ...

# %%
#removed $ from salary columns 
r3['sal_1']=r3.sal_1.apply(lambda x: x.strip('$') if x.startswith('$') else x)

# %%
#removed , from salary columns  
r3['sal_1'] = r3.sal_1.apply(lambda x: x.replace(',', '') if ',' in x else x)

# %%
r3
# Out:
#                                               title  \
# 0                                    Data Scientist
# 1         Data Scientist - Nationwide Opportunities
# 2                             Senior Data Scientist
# 3                          Principal Data Scientist
# 4                                    Data Scientist
# ...                                             ...
# 1806  Data Analyst (80k - 110k + HYBRID + BENEFITS)
# 1807                                   Data Analyst
# 1808               Director of Data & Media Science
# 1809               Machine Learning Product Manager
# 1810              Digital Data Analytics Specialist
#
#                            company                            salary  \
# 0                           Oracle   [$99,333, -, $178,795, a, year]
# 1        Amazon Web Services, Inc.  [$119,300, -, $160,000, a, year]
# 2                          Verizon  [$117,000, -, $217,000, a, year]
# ...

# %%
#changed sal_1 entries to floats
r3['sal_1'] = r3['sal_1'].apply(float)

# %%
r3
# Out:
#                                               title  \
# 0                                    Data Scientist
# 1         Data Scientist - Nationwide Opportunities
# 2                             Senior Data Scientist
# 3                          Principal Data Scientist
# 4                                    Data Scientist
# ...                                             ...
# 1806  Data Analyst (80k - 110k + HYBRID + BENEFITS)
# 1807                                   Data Analyst
# 1808               Director of Data & Media Science
# 1809               Machine Learning Product Manager
# 1810              Digital Data Analytics Specialist
#
#                            company                            salary  \
# 0                           Oracle   [$99,333, -, $178,795, a, year]
# 1        Amazon Web Services, Inc.  [$119,300, -, $160,000, a, year]
# 2                          Verizon  [$117,000, -, $217,000, a, year]
# ...

# %%
r3['sal_2']=r3.sal_2.apply(lambda x: x.strip('$') if x.startswith('$') else x)

# %%
r3['sal_2'] = r3.sal_2.apply(lambda x: x.replace(',', '') if ',' in x else x)

# %%
#changed sal_2 entries to floats
r3['sal_2'] = r3['sal_2'].apply(float)

# %%
r3
# Out:
#                                               title  \
# 0                                    Data Scientist
# 1         Data Scientist - Nationwide Opportunities
# 2                             Senior Data Scientist
# 3                          Principal Data Scientist
# 4                                    Data Scientist
# ...                                             ...
# 1806  Data Analyst (80k - 110k + HYBRID + BENEFITS)
# 1807                                   Data Analyst
# 1808               Director of Data & Media Science
# 1809               Machine Learning Product Manager
# 1810              Digital Data Analytics Specialist
#
#                            company                            salary  \
# 0                           Oracle   [$99,333, -, $178,795, a, year]
# 1        Amazon Web Services, Inc.  [$119,300, -, $160,000, a, year]
# 2                          Verizon  [$117,000, -, $217,000, a, year]
# ...

# %%
r3['salary_avg'] = r3[['sal_1','sal_2']].mean(axis=1)

# %% [markdown]
# - Decided to average the salary columns to obtain one salary column for each entry

# %%
r3
# Out:
#                                               title  \
# 0                                    Data Scientist
# 1         Data Scientist - Nationwide Opportunities
# 2                             Senior Data Scientist
# 3                          Principal Data Scientist
# 4                                    Data Scientist
# ...                                             ...
# 1806  Data Analyst (80k - 110k + HYBRID + BENEFITS)
# 1807                                   Data Analyst
# 1808               Director of Data & Media Science
# 1809               Machine Learning Product Manager
# 1810              Digital Data Analytics Specialist
#
#                            company                            salary  \
# 0                           Oracle   [$99,333, -, $178,795, a, year]
# 1        Amazon Web Services, Inc.  [$119,300, -, $160,000, a, year]
# 2                          Verizon  [$117,000, -, $217,000, a, year]
# ...

# %%
#filetered entries that had salary hourly, daily, monthly or weekly
hour = r3[r3['rate']=='hour']
week = r3[r3['rate']=='week']
month = r3[r3['rate']=='month']
day = r3[r3['rate']=='day']

# %%
#removed all non-yearly salaries from df
r3 = r3.drop(r3[r3['rate']=='hour'].index)
r3 = r3.drop(r3[r3['rate']=='week'].index)
r3 = r3.drop(r3[r3['rate']=='month'].index)
r3 = r3.drop(r3[r3['rate']=='day'].index)

# %%
r3.shape
# Out:
# (1356, 9)

# %%
#multiply avg hour salary * 40 hour work week * 52 weeks in a year for annual salary
hour['salary_avg'] = hour['salary_avg']*40*52
hour
# Out:
# /var/folders/__/62t344bn4xzcnjnfq6dz75_w0000gp/T/ipykernel_83814/3380577944.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hour['salary_avg'] = hour['salary_avg']*40*52
#                                                   title  \
# 13                  Data and Insights Analyst Associate
# 14                                     HIM Data Analyst
# 16                Data Analyst Supply Chain Informatics
# 21                             Training Quality Analyst
# 35    Genomic Scientist - Data Analyst - PhD Lab Med...
# ...                                                 ...
# 1793                                Non-IT Data Analyst
# 1795                     Healthcare Claims Data Analyst
# ...

# %%
#multiply avg week salary * 52 weeks in a year for annual salary
week['salary_avg'] = week['salary_avg']*52
# Out:
# /var/folders/__/62t344bn4xzcnjnfq6dz75_w0000gp/T/ipykernel_83814/669821843.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   week['salary_avg'] = week['salary_avg']*52

# %%
week
# Out:
#                             title                  company             salary  \
# 1341  SENIOR IT BUSINESS ANALYSTS  Enterprise People, Inc.  [$1,000, a, week]
#
#             City State   sal_1   sal_2  rate  salary_avg
# 1341  Washington    DC  1000.0  1000.0  week     52000.0

# %%
#multiply month salary by 12 months for annual salary
month['salary_avg'] = month['salary_avg']*12
month
# Out:
# /var/folders/__/62t344bn4xzcnjnfq6dz75_w0000gp/T/ipykernel_83814/2738908212.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   month['salary_avg'] = month['salary_avg']*12
#                                                   title  \
# 76    Business Analyst – Technology Investment Programs
# 229                             Data Governance Analyst
# 235                                    Business Analyst
# 305        Software Engineer Advisor - Machine Learning
# 396                Applied Scientist - Machine Learning
# ...                                                 ...
# 1463                        Crime Analyst Administrator
# 1479                                         HR Analyst
# ...

# %%
#multiply avg day salary by 5 days a week * 52 weeks a year
day['salary_avg'] = day['salary_avg']*5*52
day
# Out:
# /var/folders/__/62t344bn4xzcnjnfq6dz75_w0000gp/T/ipykernel_83814/3987235260.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day['salary_avg'] = day['salary_avg']*5*52
#                             title                  company  \
# 1421  Business Analyst/Hedge Fund              Fintova LLC
# 1698      Senior Business Analyst    First Tier Technology
# 1763  Regulatory Business Analyst  Primary Talent Partners
#
#                          salary         City State   sal_1   sal_2 rate  \
# 1421  [$800, -, $1,600, a, day]        Miami    FL   800.0  1600.0  day
# 1698    [$500, -, $700, a, day]  Jersey City    NJ   500.0   700.0  day
# 1763           [$1,100, a, day]  Jersey City    NJ  1100.0  1100.0  day
#
#       salary_avg
# ...

# %% [markdown]
# - Limitation in converting the non-yearly salaries to yearly is that the role may not be for a full year, ie may be a contract for set length (6 months etc.)
# - However, extrapolated to a year and made the assumption to include the entries in my dataset

# %%
# added converted salaries back to original df
clean_data = pd.concat([r3, hour, month, week, day]).reset_index()
clean_data
# Out:
#       index                                      title  \
# 0         0                             Data Scientist
# 1         1  Data Scientist - Nationwide Opportunities
# 2         2                      Senior Data Scientist
# 3         3                   Principal Data Scientist
# 4         4                             Data Scientist
# ...     ...                                        ...
# 1806   1751    Board Certified Behavior Analyst (BCBA)
# 1807   1341                SENIOR IT BUSINESS ANALYSTS
# 1808   1421                Business Analyst/Hedge Fund
# 1809   1698                    Senior Business Analyst
# 1810   1763                Regulatory Business Analyst
#
#                         company                            salary  \
# 0                        Oracle   [$99,333, -, $178,795, a, year]
# 1     Amazon Web Services, Inc.  [$119,300, -, $160,000, a, year]
# 2                       Verizon  [$117,000, -, $217,000, a, year]
# ...

# %%
clean_data.drop(axis=1, columns='index', inplace=True)

# %%
clean_data
# Out:
#                                           title                    company  \
# 0                                Data Scientist                     Oracle
# 1     Data Scientist - Nationwide Opportunities  Amazon Web Services, Inc.
# 2                         Senior Data Scientist                    Verizon
# 3                      Principal Data Scientist                    Verizon
# 4                                Data Scientist               Appcast Inc.
# ...                                         ...                        ...
# 1806    Board Certified Behavior Analyst (BCBA)         Ross Therapy Group
# 1807                SENIOR IT BUSINESS ANALYSTS    Enterprise People, Inc.
# 1808                Business Analyst/Hedge Fund                Fintova LLC
# 1809                    Senior Business Analyst      First Tier Technology
# 1810                Regulatory Business Analyst    Primary Talent Partners
#
# ...

# %%
#removed original salary column and sal_1 and sal_2 cols 
clean_data.drop(axis=1, columns=['salary', 'sal_1', 'sal_2'], inplace=True)
clean_data
# Out:
#                                           title                    company  \
# 0                                Data Scientist                     Oracle
# 1     Data Scientist - Nationwide Opportunities  Amazon Web Services, Inc.
# 2                         Senior Data Scientist                    Verizon
# 3                      Principal Data Scientist                    Verizon
# 4                                Data Scientist               Appcast Inc.
# ...                                         ...                        ...
# 1806    Board Certified Behavior Analyst (BCBA)         Ross Therapy Group
# 1807                SENIOR IT BUSINESS ANALYSTS    Enterprise People, Inc.
# 1808                Business Analyst/Hedge Fund                Fintova LLC
# 1809                    Senior Business Analyst      First Tier Technology
# 1810                Regulatory Business Analyst    Primary Talent Partners
#
#                City State   rate  salary_avg
# ...

# %% [markdown]
# **We want to predict a binary variable - whether the salary was low or high. Compute the median salary and create a new binary variable that is true when the salary is high (above the median).**
#
# We could also perform Linear Regression (or any regression) to predict the salary value here. Instead, we are going to convert this into a _binary_ classification problem, by predicting two classes, HIGH vs LOW salary.

# %%
clean_data.salary_avg.describe()
# Out:
# count      1811.000000
# mean      95145.715461
# std       37645.687780
# min       20800.000000
# 25%       68570.000000
# 50%       88823.000000
# 75%      115000.000000
# max      367000.000000
# Name: salary_avg, dtype: float64

# %%
#created a list of the salary values separated as high if > median or low if < median 
hi_low = []
for i in clean_data['salary_avg']:
    if i > clean_data.salary_avg.median():
        hi_low.append('high')
    else:
        hi_low.append('low')
# hi_low

# %%
#added high/low col to df
clean_data['sal_hilo'] = hi_low

# %%
clean_data['sal_hilo'].value_counts(normalize=True)
# Out:
# low     0.500276
# high    0.499724
# Name: sal_hilo, dtype: float64

# %%
clean_data.dtypes
# Out:
# title          object
# company        object
# City           object
# State          object
# rate           object
# salary_avg    float64
# sal_hilo       object
# dtype: object

# %%
#save clean data 
clean_data.to_csv('web scrapes/final_data.csv')
